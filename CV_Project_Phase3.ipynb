# %%
# !pip install opencv-python numpy matplotlib

# %%
# !pip install inference
# !pip install supervision
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 4.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 46.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 51.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 3.4 MB/s eta 0:00:00
# ...

# %%
# 🔧 Install dependencies
# !pip install torch torchvision --quiet

import torch
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from google.colab import files

# 🧠 Load YOLOv5 large model
model = torch.hub.load('ultralytics/yolov5', 'yolov5l', trust_repo=True)

# 📌 Constants for triangulation
FOCAL_LENGTH = 700  # in pixels
BASELINE = 1      # in meters

# 🎯 Detect all objects and return a list of {center_x, bbox, label, confidence, cropped_image}
def detect_objects(image_path):
    image = cv2.imread(image_path)
    if image is None:
        print(f"❌ Error: Could not read image {image_path}")
        return None, None, None, None

    img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = model(img_rgb)
    detections = results.xyxy[0].cpu().numpy()

    detected_objects = []
    for det in detections:
        x1, y1, x2, y2, conf, cls_id = det
        x1, y1, x2, y2 = map(int, [x1, y1, x2, y2])
        center_x = (x1 + x2) / 2
        center_y = (y1 + y2) / 2
        label = model.names[int(cls_id)]
        cropped = image[y1:y2, x1:x2]
        detected_objects.append({
            "center_x": center_x,
            "center_y": center_y,
            "bbox": (x1, y1, x2, y2),
            "label": label,
            "confidence": conf,
            "cropped": cropped
        })

    return detected_objects, image, image.shape[1], image_path

# 📏 Estimate distance using triangulation
def estimate_distance_from_disparity(x1, x2, img_width, focal_length, baseline):
    cx = img_width / 2
    theta1 = np.arctan((x1 - cx) / focal_length)
    theta2 = np.arctan((x2 - cx) / focal_length)

    if abs(np.tan(theta1) - np.tan(theta2)) < 1e-5:
        print("⚠️ Angle difference too small for triangulation.")
        return None

    distance = abs(baseline / (np.tan(theta1) - np.tan(theta2)))
    return distance

# 🔎 ORB-based matching
def orb_match(img1, img2):
    orb = cv2.ORB_create(nfeatures=1000)
    kp1, des1 = orb.detectAndCompute(cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY), None)
    kp2, des2 = orb.detectAndCompute(cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY), None)

    if des1 is None or des2 is None:
        return 0

    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
    matches = bf.match(des1, des2)
    return len(matches)

# 🔁 Upload images
print("📤 Upload two images of the same scene (left and right views):")
uploaded = files.upload()
image_paths = list(uploaded.keys())

# 🚀 Process if exactly 2 images are uploaded
if len(image_paths) != 2:
    print("❗ Please upload exactly two images.")
else:
    objects1, full_img1, width1, path1 = detect_objects(image_paths[0])
    objects2, full_img2, width2, path2 = detect_objects(image_paths[1])

    if objects1 is None or objects2 is None:
        print("❌ Error processing images.")
    else:
        # ✅ Find common class labels
        labels1 = set(obj['label'] for obj in objects1)
        labels2 = set(obj['label'] for obj in objects2)
        common_labels = labels1 & labels2

        best_match = None
        max_matches = 0

        for label in common_labels:
            if label == "person":
                continue  # Skip 'person' label
            objs1 = [obj for obj in objects1 if obj['label'] == label]
            objs2 = [obj for obj in objects2 if obj['label'] == label]

            for o1 in objs1:
                for o2 in objs2:
                    matches = orb_match(o1['cropped'], o2['cropped'])
                    if matches > max_matches:
                        max_matches = matches
                        best_match = (o1, o2)

        if best_match:
            o1, o2 = best_match
            distance = estimate_distance_from_disparity(
                o1['center_x'], o2['center_x'], width1, FOCAL_LENGTH, BASELINE
            )

            # Draw only the matched object on both images
            for img, obj in [(full_img1, o1), (full_img2, o2)]:
                x1, y1, x2, y2 = obj['bbox']
                cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(img, obj['label'], (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
                cv2.circle(img, (int(obj['center_x']), int(obj['center_y'])), 5, (0, 0, 255), -1)

            print(f"\n✅ Matched object: {o1['label']} with {max_matches} ORB matches")
            if distance:
                print(f"📏 Estimated distance: {distance:.2f} meters")

            print("\n🖼️ Matched object in left image:")
            cv2_imshow(full_img1)
            print("\n🖼️ Matched object in right image:")
            cv2_imshow(full_img2)
        else:
            print("❌ No good object match found using ORB.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 56.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 46.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 19.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 58.8 MB/s eta 0:00:00
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# Creating new Ultralytics Settings v0.0.6 file ✅
# ...
